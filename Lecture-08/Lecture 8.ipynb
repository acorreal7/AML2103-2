# %% [markdown]
# ### Lecture 8. Nov 1, 2023

# %%
#%pip install seaborn
#%pip install pandas
#%pip install matplotlib

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# Options for pandas
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# Options for matplotlib
# %matplotlib inline
plt.style.use('seaborn-v0_8')
mpl.rcParams['figure.dpi'] = 120

# Read the file
df = pd.read_csv('./CustomersTransactions2021.csv')

# %%
df.shape
# Out:
# (34, 9)

# %%
df.head(50)
# Out:
#     customer_id  id txn_type  txn_total           Customers  Products  \
# 0          1001   1    Debit     165.78      Johnny Awesome         3
# 1          1001   2   Credit      42.10      Johnny Awesome         3
# 2          1001   4   Credit     103.03      Johnny Awesome         3
# 3          1001   5   Credit      56.60      Johnny Awesome         3
# 4          1002   6    Debit     214.34          Bob Marley         4
# 5          1002   7     Cash     115.69          Bob Marley         4
# 6          1002   8    Debit      21.37          Bob Marley         4
# 7          1004   9     Cash     227.58        Taylor Swift         2
# 8          1004  10   Credit       5.92        Taylor Swift         2
# 9          1006  11    Debit     225.89       Stephen Smith         5
# 10         1014  12     Cash      67.96       Delilah Avery         2
# 11         1014  20    Debit     449.39       Delilah Avery         2
# ...

# %%
df['id']
# Out:
# 0      1
# 1      2
# 2      4
# 3      5
# 4      6
# 5      7
# 6      8
# 7      9
# 8     10
# 9     11
# 10    12
# 11    20
# 12    28
# 13    13
# 14    21
# 15    29
# 16    14
# 17    22
# 18    30
# 19    15
# 20    23
# 21    31
# 22    16
# 23    24
# 24    32
# 25    17
# 26    25
# 27    33
# 28    18
# 29    26
# 30    34
# 31    19
# 32    27
# 33    35
# Name: id, dtype: int64

# %%
# Sort by column 'id'
df.sort_values(by='id', inplace=True)

# %%
df['id']
# Out:
# 0      1
# 1      2
# 2      4
# 3      5
# 4      6
# 5      7
# 6      8
# 7      9
# 8     10
# 9     11
# 10    12
# 13    13
# 16    14
# 19    15
# 22    16
# 25    17
# 28    18
# 31    19
# 11    20
# 14    21
# 17    22
# 20    23
# 23    24
# 26    25
# 29    26
# 32    27
# 12    28
# 15    29
# 18    30
# 21    31
# 24    32
# 27    33
# 30    34
# 33    35
# Name: id, dtype: int64

# %%
plt.figure(figsize=(8, 4))
plt.plot(df['id'], df['txn_total'])
plt.title('Linegraph of txn_total')
plt.ylabel('Transaction ammount in $', rotation=0, labelpad=50)
plt.xlabel('Transaction Id')
plt.legend()
plt.show();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(8, 4))
plt.plot(df['id'], df['txn_total'], "r--", label="Transaction ammounts")
plt.title('Linegraph of txn_total')
plt.ylabel('Transaction ammount in $', rotation=0, labelpad=50)
plt.xlabel('Transaction Id')
plt.legend()

# %%
plt.figure(figsize=(15, 5))
plt.plot(df['id'], df['txn_total'], "m--o", label="Transaction ammounts")
plt.title('Linegraph of txn_total')
plt.ylabel('Transaction ammount in $', rotation=0, labelpad=50)
plt.xlabel('Transaction Id')
plt.legend()

# %%
import numpy as np

plt.figure(figsize=(15, 5))
plt.plot(df['id'], df['txn_total'], "m--o", label="Transaction ammounts")
plt.title('Linegraph of txn_total')
plt.ylabel('Transaction ammount in $', rotation=0, labelpad=50)
plt.xlabel('Transaction Id')

# Print markers
for x, y in zip(df['id'], df['txn_total']):
    label = "{:.2f}".format(y)
    plt.annotate(label, xy=(x, y), fontsize=12, color="green")
plt.legend()

# %% [markdown]
# #### 2. Histogram

# %%
plt.figure(figsize=(15, 5))
n, bin_ranges, n_bins = plt.hist(df['txn_total'], bins=10, label='txn_total')
plt.title('Histogram of txn_total')
plt.ylabel('Frequency')
plt.xlabel('Total')
plt.legend()

# %%
print("n:", n)
print("bin_ranges:", bin_ranges)
print("n_bins:", n_bins)
# Out:
# n: [4. 4. 3. 4. 4. 6. 2. 2. 3. 2.]
# bin_ranges: [  5.92   50.267  94.614 138.961 183.308 227.655 272.002 316.349 360.696
#  405.043 449.39 ]
# n_bins: <BarContainer object of 10 artists>

# %% [markdown]
# #### 3. Boxplot

# %%
df['txn_total'].describe()
# Out:
# count     34.000000
# mean     207.296765
# std      124.283187
# min        5.920000
# 25%      106.195000
# 50%      220.115000
# 75%      273.582500
# max      449.390000
# Name: txn_total, dtype: float64

# %%
plt.figure(figsize=(8, 4))
plt.boxplot(df['txn_total'], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x147046700>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x147046a30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x147046460>],
#  'medians': [<matplotlib.lines.Line2D at 0x147046f70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x147053250>],
#  'means': []}

# %% [markdown]
# #### Subplots

# %%
df['Customers'].unique()
# Out:
# array(['Johnny Awesome', 'Bob Marley', 'Taylor Swift', 'Stephen Smith',
#        'Delilah Avery', 'Johnson Cory', 'Maria Alva', 'Jessica Fast',
#        'Mariah Anita Smith', 'Robert Optimus', 'Steven Prime',
#        'Stephanie Element'], dtype=object)

# %%
fig, ax = plt.subplots(2, 3)

# %%
# Assign subplots to variables ax1 ... ax6
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3)

# %%
# Assign subplots to variables ax1 ... ax6 and share ticks
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, sharey=True, sharex=True, figsize=(10, 5))

# %%
# Assign subplots to variables ax1 ... ax6 and share ticks
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, sharey=True, sharex=True, figsize=(10, 5))

# 
def plot_customer_data(ax, customer_name, style):
    ax.plot(
        df[df['Customers'] == customer_name]["id"],
        df[df['Customers'] == customer_name]["txn_total"],
        style
    )
    ax.set_title(customer_name)

plot_customer_data(ax1, 'Johnny Awesome', "co--")
plot_customer_data(ax2, 'Bob Marley', "m.--")
plot_customer_data(ax3, 'Taylor Swift', "g*--")
plot_customer_data(ax4, 'Stephen Smith', "ro--")
plot_customer_data(ax5, 'Delilah Avery', "y+--")
plot_customer_data(ax6, 'Johnson Cory', "b*--")

# %%
# Assign subplots to variables ax1 ... ax6 and share ticks
fig, ax = plt.subplots()

# 
def plot_customer_data(ax, customer_name, style):
    ax.plot(
        df[df['Customers'] == customer_name]["id"],
        df[df['Customers'] == customer_name]["txn_total"],
        style
    )
    ax.set_title(customer_name)

plot_customer_data(ax, 'Johnny Awesome', "co--")
plot_customer_data(ax, 'Bob Marley', "m.--")
plot_customer_data(ax, 'Taylor Swift', "g*--")
plot_customer_data(ax, 'Stephen Smith', "ro--")
plot_customer_data(ax, 'Delilah Avery', "y+--")
plot_customer_data(ax, 'Johnson Cory', "b*--")

# %% [markdown]
# #### 5 Bargraphs

# %%
df['Category'].unique()
# Out:
# array(['wealth', 'personal_banking', 'hnw'], dtype=object)

# %%
df.groupby(by='Category').agg({ 'txn_total': 'sum' }).plot(kind='bar', width=0.7)
plt.title('Total txn_total per category')
plt.xlabel('Category')
plt.ylabel('Total')
plt.xticks(rotation=0)
plt.legend()

# %%
sum_data = df.groupby(by='Category')['txn_total'].agg('sum').reset_index()

plt.bar(sum_data['Category'], sum_data['txn_total'], label='Category', width=0.7, color='c')
plt.title('Total txn_total per category')
plt.xlabel('Category')
plt.ylabel('Total')
plt.legend()

# %% [markdown]
# ### Lecture 9. Nov 8, 2023

# %%
df.head(2)
# Out:
#    customer_id  id txn_type  txn_total       Customers  Products Province  \
# 0         1001   1    Debit     165.78  Johnny Awesome         3       ON
# 1         1001   2   Credit      42.10  Johnny Awesome         3       ON
#
#    Relationship Category
# 0             1   wealth
# 1             1   wealth

# %%
# Group by multiple columns

df.groupby(by=['Category', 'txn_type']).agg({ 'txn_total': 'sum' }) # Result as a Datafraame
# Out:
#                            txn_total
# Category         txn_type
# hnw              Cash         652.01
#                  Credit       451.15
#                  Debit        461.68
# personal_banking Cash         961.75
#                  Credit       815.55
#                  Debit       1668.49
# wealth           Cash         391.13
#                  Credit       595.64
#                  Debit       1050.69

# %%
df.groupby(by=['Category', 'txn_type'])['txn_total'].sum() # Result as a Serie
# Out:
# Category          txn_type
# hnw               Cash         652.01
#                   Credit       451.15
#                   Debit        461.68
# personal_banking  Cash         961.75
#                   Credit       815.55
#                   Debit       1668.49
# wealth            Cash         391.13
#                   Credit       595.64
#                   Debit       1050.69
# Name: txn_total, dtype: float64

# %%
df.groupby(by=['Category', 'txn_type']).agg({ 'txn_total': 'sum' }).unstack('txn_type')
# Out:
#                  txn_total
# txn_type              Cash  Credit    Debit
# Category
# hnw                 652.01  451.15   461.68
# personal_banking    961.75  815.55  1668.49
# wealth              391.13  595.64  1050.69

# %%
df.groupby(by=['Category', 'txn_type']) \
    .agg({ 'txn_total': 'sum' }) \
    .unstack('txn_type') \
    .plot(kind='bar', stacked=True)
plt.title('Total per banking and transaction type')
plt.xlabel('Catgory')
plt.ylabel('Total')
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'hnw'), Text(1, 0, 'personal_banking'), Text(2, 0, 'wealth')])

# %% [markdown]
# ### Scatter plot

# %%
# Create new column with random data
min_balance = df['txn_total'].max()
size = len(df)
max_balance = 5000
df['acct_balance'] = np.random.randint(min_balance, max_balance, size)
df.head(5)
# Out:
#    customer_id  id txn_type  txn_total       Customers  Products Province  \
# 0         1001   1    Debit     165.78  Johnny Awesome         3       ON
# 1         1001   2   Credit      42.10  Johnny Awesome         3       ON
# 2         1001   4   Credit     103.03  Johnny Awesome         3       ON
# 3         1001   5   Credit      56.60  Johnny Awesome         3       ON
# 4         1002   6    Debit     214.34      Bob Marley         4       ON
#
#    Relationship          Category  acct_balance
# 0             1            wealth          4783
# 1             1            wealth          2349
# 2             1            wealth          2726
# 3             1            wealth          2537
# 4             1  personal_banking          3606

# %%
plt.scatter(df['acct_balance'], df['txn_total'], c='m')
plt.title('Scatterplit of acct_balance and txn_total')
plt.xlabel('acct_balance')
plt.ylabel('txn_total')
plt.show();

# %% [markdown]
# ### Seaborn

# %%
import seaborn as sns

sns.lmplot(data=df, x='acct_balance', y='txn_total', markers='+')
plt.title('Scatterplit of acct_balance and txn_total')
plt.xlabel('acct_balance')
plt.ylabel('txn_total')
plt.show();
# Out:
# /Users/jesusandrescorrealortiz/Library/Python/3.9/lib/python/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### Boxplot in seaborn

# %%
import seaborn as sns

sns.boxplot(data=df, x='Category', y='txn_total')
plt.title('Scatterplit of acct_balance and txn_total')
plt.xlabel('acct_balance')
plt.ylabel('txn_total')
plt.show();

# %%
sns.pairplot(df)
# Out:
# /Users/jesusandrescorrealortiz/Library/Python/3.9/lib/python/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df, hue='txn_type')
# Out:
# /Users/jesusandrescorrealortiz/Library/Python/3.9/lib/python/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
corr = df.corr(numeric_only=True)
matrix = np.triu(corr)
sns.heatmap(corr, annot=True, vmin=-1, vmax=1, cmap='Blues', mask=matrix)
# Out:
# <Axes: >

# %% [markdown]
# ### Distplot

# %%
sns.distplot(df['txn_total'], )
# Out:
# /var/folders/v5/v6n5dfsn6r33r6_wf97yqn7r0000gn/T/ipykernel_5141/4171095472.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['txn_total'], )
# <Axes: xlabel='txn_total', ylabel='Density'>

# %% [markdown]
# ### Bubble chart

# %%
df.head(2)
# Out:
#    customer_id  id txn_type  txn_total       Customers  Products Province  \
# 0         1001   1    Debit     165.78  Johnny Awesome         3       ON
# 1         1001   2   Credit      42.10  Johnny Awesome         3       ON
#
#    Relationship Category  acct_balance
# 0             1   wealth          4783
# 1             1   wealth          2349

# %%
sns.scatterplot(data=df, x='customer_id', y='txn_total', hue='txn_type', size='acct_balance')
plt.legend(loc=1, bbox_to_anchor=(1.3, 1))
plt.title('Scatter plot with x, y, size and color')
# Out:
# Text(0.5, 1.0, 'Scatter plot with x, y, size and color')
